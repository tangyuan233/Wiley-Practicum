# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sns
from nltk.corpus import stopwords
from nltk import word_tokenize,ne_chunk,pos_tag
from nltk.util import ngrams
import itertools
import networkx as nx
from networkx.algorithms import community

# %%
f = open('all.txt', encoding='utf-8').read()
coauthor = []
n = 1
for item in f:
    start = f.find('AU ', n)
    end = f.find('AF ', start)
    if start != -1:
        pb = f.find('PT ',n)
        start = f.find('AU ',pb)
        end = f.find('AF ',start)
        result = f[start:end]
        ed = f.find('ER ', end)
        co = result.find('\n ',start)
        name = result[co+3:]
        coauthor.append(name)
        n = ed + 1
    else:
        break

# %%
s = open('all.txt', encoding='utf-8').read()
title = []
n = 1
for item in s:
    start = s.find('TI ', n)
    end = s.find('SO ', start)
    if start != -1:
        pb = s.find('AF ',n)
        start = s.find('TI ',pb)
        end = s.find('SO ',start)
        result = s[start:end]
        ed = s.find('ER ', end)
        co = result.find('\n ',start)
        ab = result[co+3:]
        title.append(ab)
        n = ed + 1
    else:
        break

# %%
title = pd.DataFrame(data=title)
title.columns = ['TI']
title.head()
# Out:
#                                                   TI
# 0   From information society to biosociety? On so...
# 1   (Un)doing gender in a rehabilitation context:...
# 2   Adhesive B-doped DLC films on biomedical allo...
# 3   Extra-/Intracellular Biosynthesis of Gold Nan...
# 4   A novel hybrid system for the fabrication of ...

# %%
coauthor = pd.DataFrame(data=coauthor)
coauthor.columns = ['CA']
coauthor.head()
# Out:
#                                                   CA
# 0                                      Ahlqvist, T\n
# 1   Ahlsen, B\n   Bondevik, H\n   Mengshoel, AM\n...
# 2                         Ahmad, AA\n   Alsaad, AM\n
# 3   Ahmad, A\n   Senapati, S\n   Khan, MI\n   Kum...
# 4   Ahmad, B\n   Gunduz, O\n   Stoyanov, S\n   Pe...

# %%
da = coauthor['CA'].str.split('\n', expand=True).stack()

# %%
da = da.reset_index(level=1, drop=True).rename('Author')

# %%
fa = coauthor['CA'].map(lambda x:x.rsplit('\n ')[0])
fa = fa.str.replace('\n', '')

# %%
fa = fa.str.replace('\n', '')

# %%
fa.head()
# Out:
# 0     Ahlqvist, T
# 1       Ahlsen, B
# 2       Ahmad, AA
# 3        Ahmad, A
# 4        Ahmad, B
# Name: CA, dtype: object

# %%
da = pd.DataFrame(data=da)
fa = pd.DataFrame(data=fa)

# %%
name = fa.join(da)

# %%
name = name[name['Author'].map(len) > 0]

# %%
name.head()
# Out:
#              CA             Author
# 0   Ahlqvist, T        Ahlqvist, T
# 1     Ahlsen, B          Ahlsen, B
# 1     Ahlsen, B        Bondevik, H
# 1     Ahlsen, B      Mengshoel, AM
# 1     Ahlsen, B     Solbraekke, KN

# %%
data = pd.read_csv('data.csv')

# %%
df = data.join(name)

# %%
df.head()
# Out:
#   Publication Type       Authors  \
# 0                J   Ahlqvist, T
# 1                J     Ahlsen, B
# 1                J     Ahlsen, B
# 1                J     Ahlsen, B
# 1                J     Ahlsen, B
#
#                                                Title  Language Document Type  \
# 0   From information society to biosociety? On so...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
#
#                                      Author Keywords Author Country  \
# 0   information society; biosociety; transition; ...        Finland
# 1     Femininity; gender; masculinity; muscles; pain         Norway
# 1     Femininity; gender; masculinity; muscles; pain         Norway
# ...

# %%
#data.index = np.arange(1,len(data)+1)
data['Authors']=author['Authors']
data['Coauthors'] = coauthor['Coauthors']

# %%
df = df[['Publication Type','Author', 'CA','Title','Language','Document Type','Author Keywords','Author Country','Cited References','Cited Reference Count','CR count','WOS Cited count','WOS Categories','Research Areas','UC 180','UC since 2013','Publisher','Publisher City','Publication Date','Year Published','Page Count']]
df.head()
# Out:
#   Publication Type             Author            CA  \
# 0                J        Ahlqvist, T   Ahlqvist, T
# 1                J          Ahlsen, B     Ahlsen, B
# 1                J        Bondevik, H     Ahlsen, B
# 1                J      Mengshoel, AM     Ahlsen, B
# 1                J     Solbraekke, KN     Ahlsen, B
#
#                                                Title  Language Document Type  \
# 0   From information society to biosociety? On so...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
# 1   (Un)doing gender in a rehabilitation context:...   English       Article
#
#                                      Author Keywords Author Country  \
# 0   information society; biosociety; transition; ...        Finland
# ...

# %%
data = df

# %%
# Split Reserach Areas
from pandas import Series, DataFrame
r = data[['Title','Research Areas','Year Published']]
ra = r['Research Areas'].str.split(';').apply(Series, 1).stack()
ra.index = ra.index.droplevel(-1)
ra.name = 'Research Areas'
del r['Research Areas']
r = r.join(ra)

# %%
r_imp = r.groupby(['Research Areas','Year Published']).size()/r.groupby(['Year Published']).size()
r_imp = pd.DataFrame(data=r_imp)

# %%
r_imp['Areas Impact'] = r.groupby(['Research Areas','Year Published']).size()/r.groupby(['Year Published']).size()

# %%
r_imp.head()
# Out:
#                                       0  Areas Impact
# Research Areas Year Published
#                1986            0.000154      0.000154
#                1987            0.003028      0.003028
#                1988            0.008952      0.008952
#                1989            0.000418      0.000418
#                1990            0.015655      0.015655

# %%
# Calculate Research Areas impact
ra_impact = pd.merge(r, r_imp,  on=['Research Areas','Year Published'])
r_impact = ra_impact[['Research Areas','Title','Year Published','Areas Impact']]
r_impact = r_impact.drop_duplicates()
r_impact = r_impact.groupby(['Title','Year Published']).sum()

# %%
# Merge impact
data = pd.merge(data, r_impact, on=['Title','Year Published'])

# %%
data.head()
# Out:
#   Publication Type          Author            CA  \
# 0                J     Ahlqvist, T   Ahlqvist, T
# 1                J        David, F      David, F
# 2                J     Tienpont, B      David, F
# 3                J       Sandra, P      David, F
# 4                J       Ahlsen, B     Ahlsen, B
#
#                                                Title  Language Document Type  \
# 0   From information society to biosociety? On so...   English       Article
# 1   From information society to biosociety? On so...   English       Article
# 2   From information society to biosociety? On so...   English       Article
# 3   From information society to biosociety? On so...   English       Article
# 4   (Un)doing gender in a rehabilitation context:...   English       Article
#
#                                      Author Keywords Author Country  \
# 0   information society; biosociety; transition; ...        Finland
# ...

# %%
# Split Author Keywords
from pandas import Series, DataFrame
a = data[['Title','Author Keywords','Year Published']]
ak = a['Author Keywords'].str.split(';').apply(Series, 1).stack()
ak.index = ak.index.droplevel(-1)
ak.name = 'Author Keywords'
del a['Author Keywords']
a = a.join(ak)

# %%
a_imp = a.groupby(['Author Keywords','Year Published']).size()/a.groupby(['Year Published']).size()
a_imp = pd.DataFrame(data = a_imp)
a_imp['Keywords Impact'] = a.groupby(['Author Keywords','Year Published']).size()/a.groupby(['Year Published']).size()

# %%
a_imp.head()
# Out:
#                                        0  Keywords Impact
# Author Keywords Year Published
#                 1986            0.106444         0.106444
#                 1987            0.066245         0.066245
#                 1988            0.082017         0.082017
#                 1989            0.066147         0.066147
#                 1990            0.088450         0.088450

# %%
ak_impact = pd.merge(a, a_imp,  on=['Author Keywords','Year Published'])
a_impact = ak_impact[['Title','Year Published','Keywords Impact']]
a_impact = a_impact.drop_duplicates()
a_impact = a_impact.groupby(['Title','Year Published']).sum()
# Merge impact
data = pd.merge(data, a_impact, on=['Title','Year Published'])

# %%
data.head()
# Out:
#   Publication Type          Author            CA  \
# 0                J     Ahlqvist, T   Ahlqvist, T
# 1                J        David, F      David, F
# 2                J     Tienpont, B      David, F
# 3                J       Sandra, P      David, F
# 4                J       Ahlsen, B     Ahlsen, B
#
#                                                Title  Language Document Type  \
# 0   From information society to biosociety? On so...   English       Article
# 1   From information society to biosociety? On so...   English       Article
# 2   From information society to biosociety? On so...   English       Article
# 3   From information society to biosociety? On so...   English       Article
# 4   (Un)doing gender in a rehabilitation context:...   English       Article
#
#                                      Author Keywords Author Country  \
# 0   information society; biosociety; transition; ...        Finland
# ...

# %%
#Calculate average impact for each publisher city every year
c = data[['Publisher City','Year Published']]
c_imp = c.groupby(['Publisher City','Year Published']).size()/c.groupby(['Year Published']).size()
c_imp['City Impact'] = c.groupby(['Publisher City','Year Published']).size()/c.groupby(['Year Published']).size()
#Merge impact
#data = pd.merge(data, c_imp, on=['Publisher City','Year Published'])

# %%
c_imp['City Impact'] = c.groupby(['Publisher City','Year Published']).size()/c.groupby(['Year Published']).size()
c_imp = pd.DataFrame(data = c_imp)

# %%
#Calculate average impact for each publisher every year
p = data[['Publisher','Year Published']]
p_imp = p.groupby(['Publisher','Year Published']).size()/p.groupby(['Year Published']).size()
p_imp = pd.DataFrame(data = p_imp)
p_imp['Publisher Impact'] = p.groupby(['Publisher','Year Published']).size()/p.groupby(['Year Published']).size()
#Merge impact
data = pd.merge(data, p_imp, on=['Publisher','Year Published'])

# %%
data = pd.merge(data, c_imp, on=['Publisher City','Year Published'])

# %%
data.head()
# Out:
#   Publication Type          Author            CA  \
# 0                J     Ahlqvist, T   Ahlqvist, T
# 1                J        David, F      David, F
# 2                J     Tienpont, B      David, F
# 3                J       Sandra, P      David, F
# 4                J        Shan, XQ      Shan, XQ
#
#                                                Title  Language  \
# 0   From information society to biosociety? On so...   English
# 1   From information society to biosociety? On so...   English
# 2   From information society to biosociety? On so...   English
# 3   From information society to biosociety? On so...   English
# 4    The dawn of a new era of biomedical publication   English
#
#          Document Type                                    Author Keywords  \
# 0              Article   information society; biosociety; transition; ...
# 1              Article   digital holographic microscopy; multicomponen...
# ...

# %%
data['Publication Data'] = data['Publication Date'].str[:4]
d = data[['Publication Date','Year Published']]
d_imp = d.groupby(['Publication Date','Year Published']).size()/d.groupby(['Year Published']).size()
d_imp = pd.DataFrame(data = d_imp)
d_imp['Month Impact'] = d.groupby(['Publication Date','Year Published']).size()/d.groupby(['Year Published']).size()
#Merge impact
data = pd.merge(data, d_imp, on=['Publication Date','Year Published'])

# %%
data = data.join(title)

# %%
data.to_csv('data.csv', encoding='utf-8', index=False)

# %%
data.to_csv('data1.csv', encoding='utf-8', index=False)

# %%
data.head()
# Out:
#   Publication Type          Author              CA  \
# 0                J     Ahlqvist, T     Ahlqvist, T
# 1                J   Doraiswami, R   Doraiswami, R
# 2                J      Tummala, R   Doraiswami, R
# 3                J         Dou, JH         Dou, JH
# 4                J          Gu, GC         Dou, JH
#
#                                                Title  Language Document Type  \
# 0   From information society to biosociety? On so...   English       Article
# 1   High early strength calcium phosphate bone ce...   English       Article
# 2   High early strength calcium phosphate bone ce...   English       Article
# 3   Subsurface microstructure of metal-on-metal h...   English       Article
# 4   Subsurface microstructure of metal-on-metal h...   English       Article
#
#                                      Author Keywords Author Country  \
# 0   information society; biosociety; transition; ...        Finland
# ...
