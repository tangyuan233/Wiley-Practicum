# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   #Data visualisation libraries 
import seaborn as sns
data = pd.read_csv('rank.csv',encoding="ISO-8859-1")
#data = pd.read_csv('data.csv',encoding="ISO-8859-1")
data.head(5)
# Out:
#   Publication Type     Coauthors       Authors  \
# 0                J       Usta, M       Akil, H
# 1                J    Ucisik, AH       Akil, H
# 2                J   Merquiol, E  Chandler, EV
# 3                J      Gilon, T  Chandler, EV
# 4                J       Marx, G  Chandler, EV
#
#                                                Title  Language  \
# 0               Science and the future of psychiatry   English
# 1               Science and the future of psychiatry   English
# 2   Multiple site analytical evaluation of a port...   English
# 3   Multiple site analytical evaluation of a port...   English
# 4   Multiple site analytical evaluation of a port...   English
#
#          Document Type                                    Author Keywords  \
# 0   Editorial Material   Morphometry; Radius; Articular surface; Radio...
# 1   Editorial Material   Morphometry; Radius; Articular surface; Radio...
# ...

# %%
data.info()
data.describe()
data.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413254 entries, 0 to 413253
# Data columns (total 26 columns):
# Publication Type         413254 non-null object
# Coauthors                413250 non-null object
# Authors                  413254 non-null object
# Title                    413254 non-null object
# Language                 413254 non-null object
# Document Type            413254 non-null object
# Author Keywords          375688 non-null object
# Author Country           413254 non-null object
# Cited References         413254 non-null object
# Cited Reference Count    413254 non-null int64
# CR count                 413254 non-null int64
# WOS Cited count          413254 non-null int64
# WOS Categories           413254 non-null object
# Research Areas           413254 non-null object
# UC 180                   413254 non-null int64
# UC since 2013            413254 non-null int64
# Publisher                413254 non-null object
# ...

# %%
#sns.pairplot(data)

# %%
#import the necessary module
from sklearn import preprocessing

# create the Labelencoder object
le = preprocessing.LabelEncoder()

#convert the categorical columns into numeric
data['Publication Type'] = le.fit_transform(data['Publication Type'])
#data['Coauthors'] = le.fit_transform(data['Coauthors'])
#print("Publication Type : ",data['Publication Type'].unique())
#data['Authors'] = le.fit_transform(data['Authors'])
#data['Title'] = le.fit_transform(data['Title'])
data['Language'] = le.fit_transform(data['Language'])
#print("Language : ",data['Language'].unique())
data['Document Type'] = le.fit_transform(data['Document Type'])
#data['Author Keywords'] = le.fit_transform(data['Author Keywords'])
#data['Author Country'] = le.fit_transform(data['Author Country'])
#data['Cited References'] = le.fit_transform(data['Cited References'])
#data['WOS Categories'] = le.fit_transform(data['WOS Categories'])
#data['Research Areas'] = le.fit_transform(data['Research Areas'])
#data['Publisher'] = le.fit_transform(data['Publisher'])
#data['Publisher City'] = le.fit_transform(data['Publisher City'])
#data['Publication Data'] = le.fit_transform(data['Publication Data'])
#data['Pagerank'] = le.fit_transform(data['Pagerank'])

#display the initial records
data.head()
# Out:
#    Publication Type  Coauthors  Authors  Title  Language  Document Type  \
# 0                 1     105629      541  32374         5              7
# 1                 1      68329      541  32374         5              7
# 2                 1      95999     5307  24860         5              0
# 3                 1      21663     5307  24860         5              0
# 4                 1      41688     5307  24860         5              0
#
#    Author Keywords  Author Country  Cited References  Cited Reference Count  \
# 0            50321             436             10124                      0
# 1            50321             436             10124                      0
# 2            56706             421              9152                      8
# 3            56706             421              9152                      8
# 4            56706             421              9152                      8
#
# ...

# %%
df = pd.DataFrame(data=data)
df_test =  df.loc[df['Year Published'].isin([2017,2018])]
df_test.head()
# Out:
#         Publication Type  Coauthors  Authors  Title  Language  Document Type  \
# 369715                 1     109074      411  28267         5             16
# 369716                 1     109074    28379  10669         5              0
# 369717                 1     109074    11673   6024         5              0
# 369718                 1      81120      414  28267         5             16
# 369719                 1      81120      804  31736         5              7
#
#         Author Keywords  Author Country  Cited References  \
# 369715            72848             213              4293
# 369716            54250             436             22733
# 369717            62693             282             27916
# 369718            47569              70             15485
# 369719            42826             278              6829
#
#         Cited Reference Count  ...  Publisher  Publisher City  Year Published  \
# ...

# %%
df = pd.DataFrame(data=data)
df_train =  df.loc[df['Year Published'].isin([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])]
df_train.head()
# Out:
#    Publication Type  Coauthors  Authors  Title  Language  Document Type  \
# 0                 1     105629      541  32374         5              7
# 1                 1      68329      541  32374         5              7
# 2                 1      95999     5307  24860         5              0
# 3                 1      21663     5307  24860         5              0
# 4                 1      41688     5307  24860         5              0
#
#    Author Keywords  Author Country  Cited References  Cited Reference Count  \
# 0            50321             436             10124                      0
# 1            50321             436             10124                      0
# 2            56706             421              9152                      8
# 3            56706             421              9152                      8
# 4            56706             421              9152                      8
#
# ...

# %%
y_test = df_test.Pagerank
X_test = df_test.drop('Pagerank', axis=1)
y_train = df_train.Pagerank
X_train = df_train.drop('Pagerank', axis=1)
#print(y_test)
print("\nX_train:\n")
#print(X_train.head())
print(X_train.shape)
print("\nX_test:\n")
#print(X_test.head())
print(X_test.shape)
# Out:
# X_train:
#
# (369715, 25)
#
# X_test:
#
# (43539, 25)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
r_sq = model.score(X_train,y_train)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
y_pred = model.predict(X_test)
print('predicted response:', y_pred)
# Out:
# ('coefficient of determination:', 0.8479910921529776)
# ('intercept:', 1140907.0907203564)
# ('slope:', array([ 1.30720726e+02,  4.52903134e-03, -4.99871337e-04, -8.14782110e-04,
#         1.03903214e+01,  1.08065961e+00,  2.10816730e-03,  1.80326077e-01,
#         5.75611056e-04,  5.63609160e-01,  5.68242874e+00, -5.15848554e+00,
#        -7.12086625e-02,  1.03233570e-01, -6.15994918e+00, -2.26904069e-01,
#         1.67227368e-01, -2.79492805e-02, -5.65098592e+02, -7.52486457e+00,
#        -1.33871925e+01,  5.42113981e-01, -9.11715998e+02,  5.47512842e-01,
#        -1.07209761e+03]))
# ('predicted response:', array([1836.34415891, 1775.68685135, 1780.99697239, ...,   18.45465168,
#          59.82735299,   10.90928546]))

# %%
plt.scatter(y_test,y_pred)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred_log=logreg.predict(X_test)
print("Logistic regression")
print(confusion_matrix(y_test, y_pred_log))  
print(classification_report(y_test, y_pred_log))
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_log))
print("Precision:",metrics.precision_score(y_test, y_pred_log))
print("Recall:",metrics.recall_score(y_test, y_pred_log))
